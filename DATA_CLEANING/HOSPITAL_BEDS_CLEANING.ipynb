# %% [markdown]
# Hospital Beds Cleaning

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adrianbarrios/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/adrianbarrios/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

data_dir = '../DATASETS'

files = [
    'HOSPITAL_BEDS_PER_10000_POPULATION.xlsx',
]

datasets = {}
for file in files:
    file_path = os.path.join(data_dir, file)
    if file.endswith('.xls') or file.endswith('.xlsx'):
        datasets[file] = pd.read_excel(file_path) # This line was asking for xlrd.

# %%
HOSPITAL_BEDS_RAW =datasets.get("HOSPITAL_BEDS_PER_10000_POPULATION.xlsx")
HOSPITAL_BEDS_RAW.head()
HOSPITAL_BEDS_RAW.columns = HOSPITAL_BEDS_RAW.iloc[1]

# Remove the first 3 rows (0, 1, 2)
HOSPITAL_BEDS = HOSPITAL_BEDS_RAW.iloc[2:].reset_index(drop=True)

# %%
HOSPITAL_BEDS.head()
# Out:
# 1 IndicatorCode                              Indicator ValueType  \
# 0      WHS6_102  Hospital beds (per 10 000 population)   numeric
# 1      WHS6_102  Hospital beds (per 10 000 population)   numeric
# 2      WHS6_102  Hospital beds (per 10 000 population)   numeric
# 3      WHS6_102  Hospital beds (per 10 000 population)   numeric
# 4      WHS6_102  Hospital beds (per 10 000 population)   numeric
#
# 1 ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 AGO
# 1                AFR         Africa       Country                 BDI
# 2                AFR         Africa       Country                 BDI
# 3                AFR         Africa       Country                 BDI
# 4                AFR         Africa       Country                 BEN
#
# 1 Location Period type Period  ... FactValueUoM FactValueNumericLowPrefix  \
# 0   Angola        Year   2019  ...          NaN                       NaN
# 1  Burundi        Year   2014  ...          NaN                       NaN
# 2  Burundi        Year   2013  ...          NaN                       NaN
# 3  Burundi        Year   2012  ...          NaN                       NaN
# 4    Benin        Year   2021  ...          NaN                       NaN
#
# 1 FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh Value  \
# 0                 NaN                        NaN                  NaN   7.5
# 1                 NaN                        NaN                  NaN   6.9
# 2                 NaN                        NaN                  NaN   7.1
# 3                 NaN                        NaN                  NaN   9.9
# 4                 NaN                        NaN                  NaN   4.3
#
# 1 FactValueTranslationID                                       FactComments  \
# 0                    NaN  Anuário de  Estatísticas Sociais 2015 - 2019, INE
# 1                    NaN      Annuaire des statistiques du Burundi, ISTEEBU
# 2                    NaN      Annuaire des statistiques du Burundi, ISTEEBU
# 3                    NaN      Annuaire des statistiques du Burundi, ISTEEBU
# 4                    NaN                        INSAE, Annuaire statistique
#
# 1 Language         DateModified
# 0       EN  2025-09-30 00:00:00
# 1       EN  2025-09-30 00:00:00
# 2       EN  2025-09-30 00:00:00
# 3       EN  2025-09-30 00:00:00
# 4       EN  2025-09-30 00:00:00
#
# [5 rows x 34 columns]

# %% [markdown]
# Dropping NaN columns.

# %%
cols_to_drop = [
    "Dim1 type",
    "Dim1",
    "Dim1ValueCode",
    "Dim2 type",
    "Dim2",
    "Dim2ValueCode",
    "Dim3 type",
    "Dim3",
    "Dim3ValueCode",
    "DataSourceDimValueCode",
    "DataSource",
    "FactValueNumericPrefix",
    "FactValueUoM",
    "FactValueNumericLowPrefix",
    "FactValueNumericLow",
    "FactValueNumericHighPrefix",
    "FactValueNumericHigh"
]

# %%
HOSPITAL_BEDS = HOSPITAL_BEDS.drop(columns=cols_to_drop)
