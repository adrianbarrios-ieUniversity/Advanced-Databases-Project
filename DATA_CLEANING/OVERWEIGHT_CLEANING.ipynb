# %%
import pandas as pd

df_ow = pd.read_excel('OVERWEIGHT_PERCENTAGE_AMONG_ADULTS_AGE_STANDARDIZED.xlsx', header=2)

print(f"Original shape: {df_ow.shape}")
print(f"\nAll columns ({len(df_ow.columns)}):")
for i, col in enumerate(df_ow.columns):
    null_pct = df_ow[col].isnull().sum() / len(df_ow) * 100
    print(f"  [{i:2d}] {col:35s} | nulls: {null_pct:5.1f}% | unique: {df_ow[col].nunique()}")
# Out:
# Original shape: (19701, 34)
#
# All columns (34):
#   [ 0] IndicatorCode                       | nulls:   0.0% | unique: 1
#   [ 1] Indicator                           | nulls:   0.0% | unique: 1
#   [ 2] ValueType                           | nulls:   0.0% | unique: 1
#   [ 3] ParentLocationCode                  | nulls:   0.0% | unique: 6
#   [ 4] ParentLocation                      | nulls:   0.0% | unique: 6
#   [ 5] Location type                       | nulls:   0.0% | unique: 1
#   [ 6] SpatialDimValueCode                 | nulls:   0.0% | unique: 199
#   [ 7] Location                            | nulls:   0.0% | unique: 199
#   [ 8] Period type                         | nulls:   0.0% | unique: 1
#   [ 9] Period                              | nulls:   0.0% | unique: 33
#   [10] IsLatestYear                        | nulls:   0.0% | unique: 2
#   [11] Dim1 type                           | nulls:   0.0% | unique: 1
#   [12] Dim1                                | nulls:   0.0% | unique: 3
#   [13] Dim1ValueCode                       | nulls:   0.0% | unique: 3
#   [14] Dim2 type                           | nulls:   0.0% | unique: 1
#   [15] Dim2                                | nulls:   0.0% | unique: 1
#   [16] Dim2ValueCode                       | nulls:   0.0% | unique: 1
#   [17] Dim3 type                           | nulls: 100.0% | unique: 0
#   [18] Dim3                                | nulls: 100.0% | unique: 0
#   [19] Dim3ValueCode                       | nulls: 100.0% | unique: 0
#   [20] DataSourceDimValueCode              | nulls: 100.0% | unique: 0
#   [21] DataSource                          | nulls: 100.0% | unique: 0
#   [22] FactValueNumericPrefix              | nulls: 100.0% | unique: 0
#   [23] FactValueNumeric                    | nulls:   0.0% | unique: 7212
#   [24] FactValueUoM                        | nulls: 100.0% | unique: 0
#   [25] FactValueNumericLowPrefix           | nulls: 100.0% | unique: 0
#   [26] FactValueNumericLow                 | nulls:   0.0% | unique: 7081
#   [27] FactValueNumericHighPrefix          | nulls: 100.0% | unique: 0
#   [28] FactValueNumericHigh                | nulls:   0.0% | unique: 7334
#   [29] Value                               | nulls:   0.0% | unique: 18278
#   [30] FactValueTranslationID              | nulls: 100.0% | unique: 0
#   [31] FactComments                        | nulls: 100.0% | unique: 0
#   [32] Language                            | nulls:   0.0% | unique: 1
#   [33] DateModified                        | nulls:   0.0% | unique: 1

# %%
print(f"Rows before filter: {len(df_ow)}")
print(f"Sex categories: {df_ow['Dim1'].unique().tolist()}")

df_ow = df_ow[df_ow['Dim1'] == 'Both sexes']

print(f"Rows after keeping only 'Both sexes': {len(df_ow)}")
# Out:
# Rows before filter: 19701
# Sex categories: ['Both sexes', 'Male', 'Female']
# Rows after keeping only 'Both sexes': 6567

# %%
df_ow = df_ow[['ParentLocationCode', 'ParentLocation', 'SpatialDimValueCode', 'Location', 'Period', 'FactValueNumeric']]

df_ow['indicator_code'] = 'NCD_BMI_25A'
df_ow['indicator_name'] = 'Prevalence of overweight among adults, BMI >= 25 (%)'

print(f"Shape after selecting columns: {df_ow.shape}")
df_ow.head()
# Out:
# Shape after selecting columns: (6567, 8)
#    ParentLocationCode ParentLocation SpatialDimValueCode Location  Period  \
# 0                 AFR         Africa                 AGO   Angola    2022
# 3                 AFR         Africa                 AGO   Angola    2021
# 6                 AFR         Africa                 AGO   Angola    2020
# 9                 AFR         Africa                 AGO   Angola    2019
# 12                AFR         Africa                 AGO   Angola    2018
#
#     FactValueNumeric indicator_code  \
# 0              31.78    NCD_BMI_25A
# 3              31.25    NCD_BMI_25A
# 6              30.73    NCD_BMI_25A
# 9              30.22    NCD_BMI_25A
# 12             29.73    NCD_BMI_25A
#
#                                        indicator_name
# 0   Prevalence of overweight among adults, BMI >= ...
# 3   Prevalence of overweight among adults, BMI >= ...
# 6   Prevalence of overweight among adults, BMI >= ...
# 9   Prevalence of overweight among adults, BMI >= ...
# 12  Prevalence of overweight among adults, BMI >= ...

# %%
df_ow = df_ow.rename(columns={
    'ParentLocationCode': 'region_id',
    'ParentLocation': 'region_name',
    'SpatialDimValueCode': 'country_code',
    'Location': 'country_name',
    'Period': 'year',
    'FactValueNumeric': 'value'
})

df_ow = df_ow[['region_id', 'region_name', 'country_code', 'country_name', 'year', 'indicator_code', 'indicator_name', 'value']]

print("Final columns:", list(df_ow.columns))
df_ow.head(10)
# Out:
# Final columns: ['region_id', 'region_name', 'country_code', 'country_name', 'year', 'indicator_code', 'indicator_name', 'value']
#    region_id region_name country_code country_name  year indicator_code  \
# 0        AFR      Africa          AGO       Angola  2022    NCD_BMI_25A
# 3        AFR      Africa          AGO       Angola  2021    NCD_BMI_25A
# 6        AFR      Africa          AGO       Angola  2020    NCD_BMI_25A
# 9        AFR      Africa          AGO       Angola  2019    NCD_BMI_25A
# 12       AFR      Africa          AGO       Angola  2018    NCD_BMI_25A
# 15       AFR      Africa          AGO       Angola  2017    NCD_BMI_25A
# 18       AFR      Africa          AGO       Angola  2016    NCD_BMI_25A
# 21       AFR      Africa          AGO       Angola  2015    NCD_BMI_25A
# 24       AFR      Africa          AGO       Angola  2014    NCD_BMI_25A
# 27       AFR      Africa          AGO       Angola  2013    NCD_BMI_25A
#
#                                        indicator_name  value
# 0   Prevalence of overweight among adults, BMI >= ...  31.78
# 3   Prevalence of overweight among adults, BMI >= ...  31.25
# 6   Prevalence of overweight among adults, BMI >= ...  30.73
# 9   Prevalence of overweight among adults, BMI >= ...  30.22
# 12  Prevalence of overweight among adults, BMI >= ...  29.73
# 15  Prevalence of overweight among adults, BMI >= ...  29.25
# 18  Prevalence of overweight among adults, BMI >= ...  28.77
# 21  Prevalence of overweight among adults, BMI >= ...  28.31
# 24  Prevalence of overweight among adults, BMI >= ...  27.85
# 27  Prevalence of overweight among adults, BMI >= ...  27.40

# %%
print("VALIDATION — Overweight Cleaned Data")
print(f"\nFinal shape: {df_ow.shape}")
print(f"\nData types:\n{df_ow.dtypes}")
print(f"\nNull values:\n{df_ow.isnull().sum()}")
print(f"\nCountries: {df_ow['country_name'].nunique()}")
print(f"Years: {df_ow['year'].min()} - {df_ow['year'].max()}")
print(f"Regions: {df_ow['region_name'].unique().tolist()}")
df_ow.sample(5, random_state=42)
# Out:
# VALIDATION — Overweight Cleaned Data
#
# Final shape: (6567, 8)
#
# Data types:
# region_id          object
# region_name        object
# country_code       object
# country_name       object
# year                int64
# indicator_code     object
# indicator_name     object
# value             float64
# dtype: object
#
# Null values:
# region_id         0
# region_name       0
# country_code      0
# country_name      0
# year              0
# indicator_code    0
# indicator_name    0
# value             0
# dtype: int64
#
# Countries: 199
# Years: 1990 - 2022
# Regions: ['Africa', 'Americas', 'Eastern Mediterranean', 'Europe', 'South-East Asia', 'Western Pacific']
#       region_id            region_name country_code country_name  year  \
# 7497        AMR               Americas          PRI  Puerto Rico  1998
# 15756      SEAR        South-East Asia          BTN       Bhutan  2017
# 13386       EUR                 Europe          KGZ   Kyrgyzstan  2015
# 8367        EMR  Eastern Mediterranean          AFG  Afghanistan  2005
# 5754        AMR               Americas          CRI   Costa Rica  2018
#
#       indicator_code                                     indicator_name  value
# 7497     NCD_BMI_25A  Prevalence of overweight among adults, BMI >= ...  56.89
# 15756    NCD_BMI_25A  Prevalence of overweight among adults, BMI >= ...  40.24
# 13386    NCD_BMI_25A  Prevalence of overweight among adults, BMI >= ...  53.13
# 8367     NCD_BMI_25A  Prevalence of overweight among adults, BMI >= ...  23.33
# 5754     NCD_BMI_25A  Prevalence of overweight among adults, BMI >= ...  64.98

# %%
from google.colab import files

df_ow.to_excel('OVERWEIGHT_CLEAN.xlsx', index=False)
files.download('OVERWEIGHT_CLEAN.xlsx')
print(f"Downloading OVERWEIGHT_CLEAN.xlsx — {len(df_ow)} rows, {len(df_ow.columns)} columns")
# Out:
# ✅ Downloading OVERWEIGHT_CLEAN.xlsx — 6567 rows, 8 columns
